# %%
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv("Cars_data.csv")

# %%
df=data.copy()

# %%
df.head(10)
# Out:
#     Make                    Model    Type  Origin DriveTrain      MSRP  \
# 0  Acura                      MDX     SUV    Asia        All  $36,945
# 1  Acura           RSX Type S 2dr   Sedan    Asia      Front  $23,820
# 2  Acura                  TSX 4dr   Sedan    Asia      Front  $26,990
# 3  Acura                   TL 4dr   Sedan    Asia      Front  $33,195
# 4  Acura               3.5 RL 4dr   Sedan    Asia      Front  $43,755
# 5  Acura  3.5 RL w/Navigation 4dr   Sedan    Asia      Front  $46,100
# 6  Acura   NSX coupe 2dr manual S  Sports    Asia       Rear  $89,765
# 7   Audi              A4 1.8T 4dr   Sedan  Europe      Front  $25,940
# 8   Audi   A41.8T convertible 2dr   Sedan  Europe      Front  $35,940
# 9   Audi               A4 3.0 4dr   Sedan  Europe      Front  $31,840
#
#     Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0  $33,337          3.5        6.0       265.0      17.0         23.0  4451.0
# ...

# %%
df.isnull()
# Out:
#       Make  Model   Type  Origin  DriveTrain   MSRP  Invoice  EngineSize  \
# 0    False  False  False   False       False  False    False       False
# 1    False  False  False   False       False  False    False       False
# 2    False  False  False   False       False  False    False       False
# 3    False  False  False   False       False  False    False       False
# 4    False  False  False   False       False  False    False       False
# ..     ...    ...    ...     ...         ...    ...      ...         ...
# 427  False  False  False   False       False  False    False       False
# 428  False  False  False   False       False  False    False       False
# 429  False  False  False   False       False  False    False       False
# 430  False  False  False   False       False  False    False       False
# 431  False  False  False   False       False  False    False       False
#
#      Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# ...

# %%
df.isnull().values.any()
# Out:
# True

# %%
df["Make"].unique()
# Out:
# array(['Acura', 'Audi', 'BMW', nan, 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrysler', 'Dodge', 'Ford', 'GMC', 'Honda', 'Hummer', 'Hyundai',
#        'Infiniti', 'Isuzu', 'Jaguar', 'Jeep', 'Kia', 'Land Rover',
#        'Lexus', 'Lincoln', 'MINI', 'Mazda', 'Mercedes-Benz', 'Mercury',
#        'Mitsubishi', 'Nissan', 'Oldsmobile', 'Pontiac', 'Porsche', 'Saab',
#        'Saturn', 'Scion', 'Subaru', 'Suzuki', 'Toyota', 'Volkswagen',
#        'Volvo'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 62

# %%
#df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df["Horsepower"].min()
# Out:
# 73.0

# %%
df["Horsepower"].max()
# Out:
# 500.0

# %%
df["Horsepower"].mean()
# Out:
# 215.76235294117646

# %%
df.drop(["Horsepower"],axis=1)
# Out:
#                        Model   Type  Origin DriveTrain      MSRP   Invoice  \
# 1             RSX Type S 2dr  Sedan    Asia      Front  $23,820   $21,761
# 2                    TSX 4dr  Sedan    Asia      Front  $26,990   $24,647
# 3                     TL 4dr  Sedan    Asia      Front  $33,195   $30,299
# 4                 3.5 RL 4dr  Sedan    Asia      Front  $43,755   $39,014
# 5    3.5 RL w/Navigation 4dr  Sedan    Asia      Front  $46,100   $41,100
# ..                       ...    ...     ...        ...       ...       ...
# 427  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565   $38,203
# 428  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565   $40,083
# 429               S80 T6 4dr  Sedan  Europe      Front  $45,210   $42,573
# 430                      V40  Wagon  Europe      Front  $26,135   $24,641
# 431                     XC70  Wagon  Europe        All  $35,145   $33,112
#
#      EngineSize  Cylinders  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# ...

# %%
df.drop(["Model"], axis=1)
# Out:
#       Type  Origin DriveTrain      MSRP   Invoice  EngineSize  Cylinders  \
# 1    Sedan    Asia      Front  $23,820   $21,761          2.0        4.0
# 2    Sedan    Asia      Front  $26,990   $24,647          2.4        4.0
# 3    Sedan    Asia      Front  $33,195   $30,299          3.2        6.0
# 4    Sedan    Asia      Front  $43,755   $39,014          3.5        6.0
# 5    Sedan    Asia      Front  $46,100   $41,100          3.5        6.0
# ..     ...     ...        ...       ...       ...         ...        ...
# 427  Sedan  Europe      Front  $40,565   $38,203          2.4        5.0
# 428  Sedan  Europe      Front  $42,565   $40,083          2.3        5.0
# 429  Sedan  Europe      Front  $45,210   $42,573          2.9        6.0
# 430  Wagon  Europe      Front  $26,135   $24,641          1.9        4.0
# 431  Wagon  Europe        All  $35,145   $33,112          2.5        5.0
#
#      Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# ...

# %%
df["Horsepower"].sort_values()
# Out:
# 152     73.0
# 151     93.0
# 408    100.0
# 174    103.0
# 70     103.0
#        ...
# 338    477.0
# 275    493.0
# 274    493.0
# 266    493.0
# 116    500.0
# Name: Horsepower, Length: 425, dtype: float64

# %%
df["Horsepower"].sort_values(ascending=False)
# Out:
# 116    500.0
# 266    493.0
# 275    493.0
# 274    493.0
# 338    477.0
#        ...
# 69     103.0
# 70     103.0
# 408    100.0
# 151     93.0
# 152     73.0
# Name: Horsepower, Length: 425, dtype: float64

# %%
df["Cylinders"].sort_values(ascending=False)
# Out:
# 266    12.0
# 275    12.0
# 416    12.0
# 120    10.0
# 116    10.0
#        ...
# 172     4.0
# 333     4.0
# 174     4.0
# 1       4.0
# 152     3.0
# Name: Cylinders, Length: 425, dtype: float64
